# %%
corpus = """Hello Welcome to Krish naik's course. Please do watch complete tutorial! to become expert in NLP. Happy Learning.
"""

print(corpus)
# Out:
# Hello Welcome to Krish naik's course. Please do watch complete tutorial! to become expert in NLP. Happy Learning.

# %%
#sentence --> paragraph
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sent in documents:
    print(sent)
# Out:
# Hello Welcome to Krish naik course.
# Please do watch complete tutorial!
# to become expert in NLP.
# Happy Learning.

# %%
#paragraph -->words
#sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Krish',
#  'naik',
#  'course',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'complete',
#  'tutorial',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.',
#  'Happy',
#  'Learning',
#  '.']

# %%
for sent in documents:
    print(word_tokenize(sent))
# Out:
# ['Hello', 'Welcome', 'to', 'Krish', 'naik', 'course', '.']
# ['Please', 'do', 'watch', 'complete', 'tutorial', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']
# ['Happy', 'Learning', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Krish',
#  'naik',
#  "'",
#  's',
#  'course',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'complete',
#  'tutorial',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.',
#  'Happy',
#  'Learning',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

token = TreebankWordTokenizer()
token.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'Krish',
#  'naik',
#  "'s",
#  'course.',
#  'Please',
#  'do',
#  'watch',
#  'complete',
#  'tutorial',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP.',
#  'Happy',
#  'Learning',
#  '.']
